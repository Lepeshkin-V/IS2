# %%
import pandas as pd

# %%
table = pd.read_excel("Table.xlsx")
print(table)
# Out:
#                                      Terminals  Next  Accept  Stack  Return  \
# 0   ! ( число true false void int float id id(     2       0      0       0
# 1   ! ( число true false void int float id id(    15       0      1       0
# 2                 + - || = >= <= > < == != ) ;     5       0      1       0
# 3                        = >= <= > < == != ) ;    60       0      0       0
# 4                                          + -     8       0      0       0
# ..                                         ...   ...     ...    ...     ...
# 61                                           )    66       0      0       0
# 62                           = >= <= > < == !=    64       1      0       0
# 63  ! ( число true false void int float id id(     1       0      0       0
# 64                                           ;     0       1      0       1
# 65                                           )     0       0      0       1
#
#     Error
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
# ..    ...
# 61      1
# 62      1
# 63      1
# 64      1
# 65      1
#
# [66 rows x 6 columns]

# %%
def oneof(liter, terminals):
  terms = terminals.split(" ")
  return liter in terms

# %%
def LL1(word):
  i = 0
  stack = [0]
  accept = 1
  liters = word.split(" ")
  l = 0
  while i != 0 or l < len(liters):
    if accept:
      liter = liters[l]
      l += 1
    if oneof(liter, table["Terminals"][i]):
      accept = table["Accept"][i]
      if table["Return"][i]:
        i = stack[-1]
        stack.pop()
      else:
        next = table['Next'][i] - 1
        if table['Stack'][i]:
          stack.append(i + 1)
        i = next
    elif table['Error'][i]:
      print("Ошибка")
      return
    else:
      i += 1
      accept = 0
    print(liter)
    print(stack)
    print(i)
    print(accept)
    print("---------------------------------------------------------")
  print("Слово принадлежит алфавиту")

# %%
s = "int id( int id , float id ) ;"

# %%
LL1(s)
# Out:
# int
# [0]
# 1
# 0
# ---------------------------------------------------------
# int
# [0, 2]
# 14
# 0
# ---------------------------------------------------------
# int
# [0, 2]
# 15
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 27
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 28
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 29
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 30
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 31
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 39
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 40
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 41
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16, 42]
# 43
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16, 42]
# 45
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16]
# 42
# 1
# ---------------------------------------------------------
# id(
# [0, 2, 16]
# 47
# 0
# ---------------------------------------------------------
# id(
# [0, 2, 16]
# 48
# 0
# ---------------------------------------------------------
# id(
# [0, 2, 16]
# 50
# 0
# ---------------------------------------------------------
# id(
# [0, 2, 16]
# 51
# 1
# ---------------------------------------------------------
# int
# [0, 2, 16, 52]
# 40
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16, 52]
# 41
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16, 52, 42]
# 43
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16, 52, 42]
# 45
# 0
# ---------------------------------------------------------
# int
# [0, 2, 16, 52]
# 42
# 1
# ---------------------------------------------------------
# id
# [0, 2, 16, 52]
# 47
# 0
# ---------------------------------------------------------
# id
# [0, 2, 16, 52]
# 49
# 0
# ---------------------------------------------------------
# id
# [0, 2, 16]
# 52
# 1
# ---------------------------------------------------------
# ,
# [0, 2, 16]
# 53
# 0
# ---------------------------------------------------------
# ,
# [0, 2, 16]
# 55
# 0
# ---------------------------------------------------------
# ,
# [0, 2, 16]
# 56
# 1
# ---------------------------------------------------------
# float
# [0, 2, 16, 57]
# 40
# 0
# ---------------------------------------------------------
# float
# [0, 2, 16, 57]
# 41
# 0
# ---------------------------------------------------------
# float
# [0, 2, 16, 57, 42]
# 43
# 0
# ---------------------------------------------------------
# float
# [0, 2, 16, 57, 42]
# 45
# 0
# ---------------------------------------------------------
# float
# [0, 2, 16, 57]
# 42
# 1
# ---------------------------------------------------------
# id
# [0, 2, 16, 57]
# 47
# 0
# ---------------------------------------------------------
# id
# [0, 2, 16, 57]
# 49
# 0
# ---------------------------------------------------------
# id
# [0, 2, 16]
# 57
# 1
# ---------------------------------------------------------
# )
# [0, 2, 16]
# 53
# 0
# ---------------------------------------------------------
# )
# [0, 2, 16]
# 54
# 0
# ---------------------------------------------------------
# )
# [0, 2, 16]
# 58
# 0
# ---------------------------------------------------------
# )
# [0, 2]
# 16
# 1
# ---------------------------------------------------------
# ;
# [0, 2]
# 17
# 0
# ---------------------------------------------------------
# ;
# [0, 2]
# 18
# 0
# ---------------------------------------------------------
# ;
# [0, 2]
# 19
# 0
# ---------------------------------------------------------
# ;
# [0, 2]
# 26
# 0
# ---------------------------------------------------------
# ;
# [0]
# 2
# 0
# ---------------------------------------------------------
# ;
# [0, 3]
# 4
# 0
# ---------------------------------------------------------
# ;
# [0, 3]
# 5
# 0
# ---------------------------------------------------------
# ;
# [0, 3]
# 6
# 0
# ---------------------------------------------------------
# ;
# [0, 3]
# 13
# 0
# ---------------------------------------------------------
# ;
# [0]
# 3
# 0
# ---------------------------------------------------------
# ;
# [0]
# 59
# 0
# ---------------------------------------------------------
# ;
# [0]
# 60
# 0
# ---------------------------------------------------------
# ;
# [0]
# 64
# 0
# ---------------------------------------------------------
# ;
# []
# 0
# 1
# ---------------------------------------------------------
# Слово принадлежит алфавиту
